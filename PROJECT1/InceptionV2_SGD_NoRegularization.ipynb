# %%
import keras
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D
import numpy as np
import tensorflow as tf
from tensorflow.python.keras.metrics import Metric
from keras import optimizers
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers
import matplotlib.pyplot as plt 
from keras.layers import Concatenate
from keras.models import Model
from keras import layers
from keras.layers import Activation,Dense,Input,BatchNormalization,Conv2D,MaxPooling2D,AveragePooling2D,GlobalAveragePooling2D,GlobalMaxPooling2D
from keras.engine.topology import get_source_inputs
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import decode_predictions
from keras.preprocessing import image

# %%
# REFERENCED FROM https://github.com/fchollet/deep-learning-models/blob/master/inception_v3.py

# %%
num_classes=100

# %%
from keras.datasets import cifar100
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
x_shape = x_train[0].shape

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
def conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1),name=None):
    x = Conv2D(filters, (num_row, num_col),strides=strides,padding=padding)(x)
    x = Activation('relu')(x)
    return x

def InceptionV2(input_shape = (32, 32, 3), classes = 100):
    X_Input = tf.keras.Input(input_shape)
    
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3
    x = conv2d_bn(X_Input,32,3,3,strides=(2,2),padding='valid')
    x = conv2d_bn(x,32,3,3,strides=(1,1),padding='valid')
    x = conv2d_bn(x,64,3,3)
    x = MaxPooling2D((3,3),strides=(2,2))(x)

    x = conv2d_bn(x,80,1,1,padding='valid')
    x = conv2d_bn(x,192,3,3,padding='valid')
    x = MaxPooling2D((3,3),strides=(2,2))(x)

    # (Inception Layer1) * 3 Times
    
    #Inception Layer1 #mixed0
    branch1_1 = conv2d_bn(x,64,1,1)
    
    branch5_5 = conv2d_bn(x,48,1,1)
    branch5_5 = conv2d_bn(branch5_5,64,3,3)

    branch3_3dbl = conv2d_bn(x,64,1,1)
    branch3_3dbl = conv2d_bn(branch3_3dbl,96,3,3)
    branch3_3dbl = conv2d_bn(branch3_3dbl,96,3,3)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,32,1,1)

    x = layers.concatenate([branch1_1,branch5_5,branch3_3dbl,branch_pool],axis=channel_axis,name='InceptionLayer1')

    #Inception Layer2
    branch1_1 = conv2d_bn(x,64,1,1)
    
    branch5_5 = conv2d_bn(x,48,1,1)
    branch5_5 = conv2d_bn(branch5_5,64,3,3)

    branch3_3dbl = conv2d_bn(x,64,1,1)
    branch3_3dbl = conv2d_bn(branch3_3dbl,96,3,3)
    branch3_3dbl = conv2d_bn(branch3_3dbl,96,3,3)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,64,1,1)

    x = layers.concatenate([branch1_1,branch5_5,branch3_3dbl,branch_pool],axis=channel_axis,name='InceptionLayer2')

    #Inception Layer3
    branch1_1 = conv2d_bn(x,64,1,1)
    
    branch5_5 = conv2d_bn(x,48,1,1)
    branch5_5 = conv2d_bn(branch5_5,64,3,3)

    branch3_3dbl = conv2d_bn(x,64,1,1)
    branch3_3dbl = conv2d_bn(branch3_3dbl,96,3,3)
    branch3_3dbl = conv2d_bn(branch3_3dbl,96,3,3)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,64,1,1)

    x = layers.concatenate([branch1_1,branch5_5,branch3_3dbl,branch_pool],axis=channel_axis,name='InceptionLayer3')

    #Inception Layer4
    branch1_1 = conv2d_bn(x,192,1,1)

    branch7_7 = conv2d_bn(x,128,1,1)
    branch7_7 = conv2d_bn(branch7_7,128,1,7)
    branch7_7 = conv2d_bn(branch7_7,192,7,1)

    branch7_7dbl = conv2d_bn(x,128,1,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,128,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,128,1,7)
    branch7_7dbl = conv2d_bn(branch7_7dbl,128,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch7_7,branch7_7dbl,branch_pool],axis=channel_axis,name='InceptionLayer4')

    #Inception Layer5
    branch1_1 = conv2d_bn(x,192,1,1)

    branch7_7 = conv2d_bn(x,160,1,1)
    branch7_7 = conv2d_bn(branch7_7,160,1,7)
    branch7_7 = conv2d_bn(branch7_7,192,7,1)

    branch7_7dbl = conv2d_bn(x,160,1,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,160,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,160,1,7)
    branch7_7dbl = conv2d_bn(branch7_7dbl,160,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch7_7,branch7_7dbl,branch_pool],axis=channel_axis,name='InceptionLayer5')

    #Inception Layer6 mixed6
    branch1_1 = conv2d_bn(x,192,1,1)

    branch7_7 = conv2d_bn(x,160,1,1)
    branch7_7 = conv2d_bn(branch7_7,160,1,7)
    branch7_7 = conv2d_bn(branch7_7,192,7,1)

    branch7_7dbl = conv2d_bn(x,160,1,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,160,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,160,1,7)
    branch7_7dbl = conv2d_bn(branch7_7dbl,160,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch7_7,branch7_7dbl,branch_pool],axis=channel_axis,name='InceptionLayer6')

    #Inception Layer7
    branch1_1 = conv2d_bn(x,192,1,1)

    branch7_7 = conv2d_bn(x,192,1,1)
    branch7_7 = conv2d_bn(branch7_7,192,1,7)
    branch7_7 = conv2d_bn(branch7_7,192,7,1)

    branch7_7dbl = conv2d_bn(x,192,1,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch7_7,branch7_7dbl,branch_pool],axis=channel_axis,name='InceptionLayer7')

    #Inception Layer8
    branch1_1 = conv2d_bn(x,192,1,1)

    branch7_7 = conv2d_bn(x,192,1,1)
    branch7_7 = conv2d_bn(branch7_7,192,1,7)
    branch7_7 = conv2d_bn(branch7_7,192,7,1)

    branch7_7dbl = conv2d_bn(x,192,1,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,7,1)
    branch7_7dbl = conv2d_bn(branch7_7dbl,192,1,7)

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch7_7,branch7_7dbl,branch_pool],axis=channel_axis,name='InceptionLayer8')

    #Inception Layer9
    branch1_1 = conv2d_bn(x,320,1,1)

    branch3_3 = conv2d_bn(x,384,1,1)
    branch3_3_1 = conv2d_bn(branch3_3,384,1,3)
    branch3_3_2 = conv2d_bn(branch3_3,384,3,1)
    branch3_3 = layers.concatenate([branch3_3_1,branch3_3_2],axis=channel_axis,name='InceptionLayer9_1')

    branch3_3dbl = conv2d_bn(x,448,1,1)
    branch3_3dbl = conv2d_bn(branch3_3dbl,348,1,1)    
    branch3_3dbl1 = conv2d_bn(branch3_3,384,1,3)
    branch3_3dbl2 = conv2d_bn(branch3_3,384,3,1)
    branch3_3dbl = layers.concatenate([branch3_3dbl1,branch3_3dbl2],axis=channel_axis,name='InceptionLayer9_2')

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch3_3,branch3_3dbl,branch_pool],axis=channel_axis,name='InceptionLayer9')

    #Inception Layer10
    branch1_1 = conv2d_bn(x,320,1,1)

    branch3_3 = conv2d_bn(x,384,1,1)
    branch3_3_1 = conv2d_bn(branch3_3,384,1,3)
    branch3_3_2 = conv2d_bn(branch3_3,384,3,1)
    branch3_3 = layers.concatenate([branch3_3_1,branch3_3_2],axis=channel_axis,name='InceptionLayer10_1')

    branch3_3dbl = conv2d_bn(x,448,1,1)
    branch3_3dbl = conv2d_bn(branch3_3dbl,348,1,1)    
    branch3_3dbl1 = conv2d_bn(branch3_3,384,1,3)
    branch3_3dbl2 = conv2d_bn(branch3_3,384,3,1)
    branch3_3dbl = layers.concatenate([branch3_3dbl1,branch3_3dbl2],axis=channel_axis,name='InceptionLayer10_2')

    branch_pool = AveragePooling2D((3,3),strides=(1,1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool,192,1,1)
    x = layers.concatenate([branch1_1,branch3_3,branch3_3dbl,branch_pool],axis=channel_axis,name='InceptionLayer10')

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dense(classes,activation='softmax',name='predictions')(x)

    model = keras.Model(inputs = X_Input, outputs = x,name='InceptionV2')

    return model

# %%
model = InceptionV2(input_shape = (32, 32, 3), classes = 100)

# %%
batch_size = 128
maxepoches = 200
learning_rate = 0.01
lr_decay = 1e-6
lr_drop = 20

def lr_scheduler(epoch):
    return learning_rate * (0.5 ** (epoch // lr_drop))
reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False)  # randomly flip images

sgd = optimizers.SGD(lr=learning_rate,decay=lr_decay, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])


# training process in a for loop with learning rate drop every 25 epoches.

history = model.fit(datagen.flow(x_train, y_train,
                                 batch_size=batch_size),
                    epochs=maxepoches,
                    validation_data=(x_test, y_test),callbacks=[callback,reduce_lr],verbose=2)

model.save_weights("/content/gdrive/My Drive/checkpoint/InceptionV2_SGD_NoRegularization.ckpt")
# Out:
# Epoch 1/200
# 391/391 - 30s - loss: 4.6056 - accuracy: 0.0088 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 2/200
# 391/391 - 27s - loss: 4.6055 - accuracy: 0.0089 - val_loss: 4.6051 - val_accuracy: 0.0100
# Epoch 3/200
# 391/391 - 28s - loss: 4.6055 - accuracy: 0.0088 - val_loss: 4.6050 - val_accuracy: 0.0096
# Epoch 4/200
# 391/391 - 28s - loss: 4.6053 - accuracy: 0.0089 - val_loss: 4.6047 - val_accuracy: 0.0132
# Epoch 5/200
# 391/391 - 27s - loss: 4.6042 - accuracy: 0.0121 - val_loss: 4.6019 - val_accuracy: 0.0181
# Epoch 6/200
# 391/391 - 28s - loss: 4.5879 - accuracy: 0.0189 - val_loss: 4.5338 - val_accuracy: 0.0188
# Epoch 7/200
# 391/391 - 28s - loss: 4.3887 - accuracy: 0.0256 - val_loss: 4.3298 - val_accuracy: 0.0278
# Epoch 8/200
# 391/391 - 27s - loss: 4.2611 - accuracy: 0.0307 - val_loss: 4.2173 - val_accuracy: 0.0397
# Epoch 9/200
# 391/391 - 28s - loss: 4.1886 - accuracy: 0.0401 - val_loss: 4.1044 - val_accuracy: 0.0488
# Epoch 10/200
# 391/391 - 28s - loss: 4.0761 - accuracy: 0.0543 - val_loss: 3.9990 - val_accuracy: 0.0623
# Epoch 11/200
# 391/391 - 28s - loss: 3.9625 - accuracy: 0.0693 - val_loss: 3.8733 - val_accuracy: 0.0785
# Epoch 12/200
# 391/391 - 28s - loss: 3.8524 - accuracy: 0.0882 - val_loss: 3.8009 - val_accuracy: 0.1001
# Epoch 13/200
# 391/391 - 28s - loss: 3.7683 - accuracy: 0.1020 - val_loss: 3.7011 - val_accuracy: 0.1118
# Epoch 14/200
# 391/391 - 28s - loss: 3.7012 - accuracy: 0.1143 - val_loss: 3.6133 - val_accuracy: 0.1316
# Epoch 15/200
# 391/391 - 28s - loss: 3.6481 - accuracy: 0.1239 - val_loss: 3.6077 - val_accuracy: 0.1255
# Epoch 16/200
# 391/391 - 28s - loss: 3.5790 - accuracy: 0.1339 - val_loss: 3.5421 - val_accuracy: 0.1444
# Epoch 17/200
# 391/391 - 28s - loss: 3.4954 - accuracy: 0.1484 - val_loss: 3.4374 - val_accuracy: 0.1536
# Epoch 18/200
# 391/391 - 28s - loss: 3.4123 - accuracy: 0.1630 - val_loss: 3.4228 - val_accuracy: 0.1617
# Epoch 19/200
# 391/391 - 28s - loss: 3.3453 - accuracy: 0.1736 - val_loss: 3.2970 - val_accuracy: 0.1908
# Epoch 20/200
# 391/391 - 28s - loss: 3.2934 - accuracy: 0.1853 - val_loss: 3.2539 - val_accuracy: 0.1948
# Epoch 21/200
# 391/391 - 27s - loss: 3.1693 - accuracy: 0.2096 - val_loss: 3.1309 - val_accuracy: 0.2203
# Epoch 22/200
# 391/391 - 28s - loss: 3.1249 - accuracy: 0.2174 - val_loss: 3.0937 - val_accuracy: 0.2297
# Epoch 23/200
# 391/391 - 28s - loss: 3.0886 - accuracy: 0.2270 - val_loss: 3.0639 - val_accuracy: 0.2381
# Epoch 24/200
# 391/391 - 28s - loss: 3.0616 - accuracy: 0.2323 - val_loss: 3.0650 - val_accuracy: 0.2333
# Epoch 25/200
# 391/391 - 28s - loss: 3.0345 - accuracy: 0.2407 - val_loss: 3.0235 - val_accuracy: 0.2442
# Epoch 26/200
# 391/391 - 29s - loss: 2.9960 - accuracy: 0.2470 - val_loss: 2.9978 - val_accuracy: 0.2494
# Epoch 27/200
# 391/391 - 28s - loss: 2.9604 - accuracy: 0.2537 - val_loss: 3.0157 - val_accuracy: 0.2481
# Epoch 28/200
# 391/391 - 28s - loss: 2.9269 - accuracy: 0.2614 - val_loss: 2.9223 - val_accuracy: 0.2637
# Epoch 29/200
# 391/391 - 28s - loss: 2.8973 - accuracy: 0.2677 - val_loss: 2.9307 - val_accuracy: 0.2675
# Epoch 30/200
# 391/391 - 28s - loss: 2.8555 - accuracy: 0.2754 - val_loss: 2.8995 - val_accuracy: 0.2718
# Epoch 31/200
# 391/391 - 28s - loss: 2.8311 - accuracy: 0.2802 - val_loss: 2.8829 - val_accuracy: 0.2786
# Epoch 32/200
# 391/391 - 28s - loss: 2.7973 - accuracy: 0.2863 - val_loss: 2.8368 - val_accuracy: 0.2856
# Epoch 33/200
# 391/391 - 28s - loss: 2.7717 - accuracy: 0.2922 - val_loss: 2.8457 - val_accuracy: 0.2878
# Epoch 34/200
# 391/391 - 28s - loss: 2.7462 - accuracy: 0.2965 - val_loss: 2.7847 - val_accuracy: 0.2966
# Epoch 35/200
# 391/391 - 28s - loss: 2.7277 - accuracy: 0.3007 - val_loss: 2.7671 - val_accuracy: 0.3005
# Epoch 36/200
# 391/391 - 28s - loss: 2.7049 - accuracy: 0.3067 - val_loss: 2.8088 - val_accuracy: 0.2913
# Epoch 37/200
# 391/391 - 28s - loss: 2.6836 - accuracy: 0.3102 - val_loss: 2.7810 - val_accuracy: 0.3061
# Epoch 38/200
# 391/391 - 28s - loss: 2.6496 - accuracy: 0.3194 - val_loss: 2.7266 - val_accuracy: 0.3037
# Epoch 39/200
# 391/391 - 28s - loss: 2.6322 - accuracy: 0.3214 - val_loss: 2.6846 - val_accuracy: 0.3184
# Epoch 40/200
# 391/391 - 28s - loss: 2.6188 - accuracy: 0.3269 - val_loss: 2.7225 - val_accuracy: 0.3126
# Epoch 41/200
# 391/391 - 28s - loss: 2.5248 - accuracy: 0.3450 - val_loss: 2.6217 - val_accuracy: 0.3372
# Epoch 42/200
# 391/391 - 28s - loss: 2.4944 - accuracy: 0.3525 - val_loss: 2.6127 - val_accuracy: 0.3396
# Epoch 43/200
# 391/391 - 28s - loss: 2.4809 - accuracy: 0.3534 - val_loss: 2.6216 - val_accuracy: 0.3365
# Epoch 44/200
# 391/391 - 28s - loss: 2.4670 - accuracy: 0.3582 - val_loss: 2.6091 - val_accuracy: 0.3394
# Epoch 45/200
# 391/391 - 28s - loss: 2.4587 - accuracy: 0.3562 - val_loss: 2.6159 - val_accuracy: 0.3417
# Epoch 46/200
# 391/391 - 28s - loss: 2.4423 - accuracy: 0.3624 - val_loss: 2.5776 - val_accuracy: 0.3428
# Epoch 47/200
# 391/391 - 28s - loss: 2.4252 - accuracy: 0.3639 - val_loss: 2.5665 - val_accuracy: 0.3453
# Epoch 48/200
# 391/391 - 28s - loss: 2.4276 - accuracy: 0.3644 - val_loss: 2.5773 - val_accuracy: 0.3475
# Epoch 49/200
# 391/391 - 28s - loss: 2.4127 - accuracy: 0.3662 - val_loss: 2.5731 - val_accuracy: 0.3481
# Epoch 50/200
# 391/391 - 28s - loss: 2.3989 - accuracy: 0.3686 - val_loss: 2.5220 - val_accuracy: 0.3611
# Epoch 51/200
# 391/391 - 27s - loss: 2.3783 - accuracy: 0.3747 - val_loss: 2.5591 - val_accuracy: 0.3487
# Epoch 52/200
# 391/391 - 27s - loss: 2.3706 - accuracy: 0.3765 - val_loss: 2.5382 - val_accuracy: 0.3566
# Epoch 53/200
# 391/391 - 27s - loss: 2.3497 - accuracy: 0.3807 - val_loss: 2.5310 - val_accuracy: 0.3549
# Epoch 54/200
# 391/391 - 28s - loss: 2.3411 - accuracy: 0.3817 - val_loss: 2.5218 - val_accuracy: 0.3533
# Epoch 55/200
# 391/391 - 27s - loss: 2.3288 - accuracy: 0.3844 - val_loss: 2.5340 - val_accuracy: 0.3618
# Epoch 56/200
# 391/391 - 27s - loss: 2.3149 - accuracy: 0.3864 - val_loss: 2.5033 - val_accuracy: 0.3626
# Epoch 57/200
# 391/391 - 27s - loss: 2.3134 - accuracy: 0.3893 - val_loss: 2.5454 - val_accuracy: 0.3543
# Epoch 58/200
# 391/391 - 27s - loss: 2.2981 - accuracy: 0.3918 - val_loss: 2.5113 - val_accuracy: 0.3599
# Epoch 59/200
# 391/391 - 27s - loss: 2.2831 - accuracy: 0.3942 - val_loss: 2.4784 - val_accuracy: 0.3664
# Epoch 60/200
# 391/391 - 27s - loss: 2.2689 - accuracy: 0.3993 - val_loss: 2.4651 - val_accuracy: 0.3664
# Epoch 61/200
# 391/391 - 28s - loss: 2.2081 - accuracy: 0.4105 - val_loss: 2.4365 - val_accuracy: 0.3796
# Epoch 62/200
# 391/391 - 28s - loss: 2.1936 - accuracy: 0.4135 - val_loss: 2.4783 - val_accuracy: 0.3737
# Epoch 63/200
# 391/391 - 28s - loss: 2.1852 - accuracy: 0.4159 - val_loss: 2.4436 - val_accuracy: 0.3782
# Epoch 64/200
# 391/391 - 28s - loss: 2.1798 - accuracy: 0.4169 - val_loss: 2.4485 - val_accuracy: 0.3782
# Epoch 65/200
# 391/391 - 28s - loss: 2.1637 - accuracy: 0.4220 - val_loss: 2.4248 - val_accuracy: 0.3835
# Epoch 66/200
# 391/391 - 28s - loss: 2.1646 - accuracy: 0.4207 - val_loss: 2.4241 - val_accuracy: 0.3812
# Epoch 67/200
# 391/391 - 28s - loss: 2.1596 - accuracy: 0.4213 - val_loss: 2.4210 - val_accuracy: 0.3818
# Epoch 68/200
# 391/391 - 28s - loss: 2.1478 - accuracy: 0.4228 - val_loss: 2.4221 - val_accuracy: 0.3822
# Epoch 69/200
# 391/391 - 28s - loss: 2.1387 - accuracy: 0.4264 - val_loss: 2.4293 - val_accuracy: 0.3800
# Epoch 70/200
# 391/391 - 28s - loss: 2.1347 - accuracy: 0.4276 - val_loss: 2.4049 - val_accuracy: 0.3869
# Epoch 71/200
# 391/391 - 29s - loss: 2.1304 - accuracy: 0.4280 - val_loss: 2.4009 - val_accuracy: 0.3889
# Epoch 72/200
# 391/391 - 28s - loss: 2.1255 - accuracy: 0.4278 - val_loss: 2.4005 - val_accuracy: 0.3868
# Epoch 73/200
# 391/391 - 28s - loss: 2.1163 - accuracy: 0.4300 - val_loss: 2.3946 - val_accuracy: 0.3883
# Epoch 74/200
# 391/391 - 28s - loss: 2.1076 - accuracy: 0.4332 - val_loss: 2.4028 - val_accuracy: 0.3872
# Epoch 75/200
# 391/391 - 28s - loss: 2.1052 - accuracy: 0.4318 - val_loss: 2.3983 - val_accuracy: 0.3841
# Epoch 76/200
# 391/391 - 28s - loss: 2.1022 - accuracy: 0.4343 - val_loss: 2.3739 - val_accuracy: 0.3894
# Epoch 77/200
# 391/391 - 28s - loss: 2.0872 - accuracy: 0.4379 - val_loss: 2.3989 - val_accuracy: 0.3875
# Epoch 78/200
# 391/391 - 28s - loss: 2.0856 - accuracy: 0.4369 - val_loss: 2.3849 - val_accuracy: 0.3884
# Epoch 79/200
# 391/391 - 28s - loss: 2.0809 - accuracy: 0.4416 - val_loss: 2.4033 - val_accuracy: 0.3892
# Epoch 80/200
# 391/391 - 28s - loss: 2.0766 - accuracy: 0.4373 - val_loss: 2.3560 - val_accuracy: 0.3968
# Epoch 81/200
# 391/391 - 28s - loss: 2.0302 - accuracy: 0.4489 - val_loss: 2.3869 - val_accuracy: 0.3964
# Epoch 82/200
# 391/391 - 28s - loss: 2.0239 - accuracy: 0.4509 - val_loss: 2.3682 - val_accuracy: 0.3997
# Epoch 83/200
# 391/391 - 28s - loss: 2.0127 - accuracy: 0.4512 - val_loss: 2.3853 - val_accuracy: 0.3938
# Epoch 84/200
# 391/391 - 28s - loss: 2.0148 - accuracy: 0.4539 - val_loss: 2.3793 - val_accuracy: 0.3943
# Epoch 85/200
# 391/391 - 28s - loss: 2.0013 - accuracy: 0.4549 - val_loss: 2.3875 - val_accuracy: 0.3951
# Epoch 86/200
# 391/391 - 28s - loss: 1.9993 - accuracy: 0.4560 - val_loss: 2.3533 - val_accuracy: 0.4010
# Epoch 87/200
# 391/391 - 28s - loss: 2.0018 - accuracy: 0.4536 - val_loss: 2.3852 - val_accuracy: 0.3940
# Epoch 88/200
# 391/391 - 28s - loss: 1.9897 - accuracy: 0.4582 - val_loss: 2.3793 - val_accuracy: 0.3968
# Epoch 89/200
# 391/391 - 28s - loss: 1.9953 - accuracy: 0.4578 - val_loss: 2.3726 - val_accuracy: 0.3981
# Epoch 90/200
# 391/391 - 27s - loss: 1.9864 - accuracy: 0.4584 - val_loss: 2.3674 - val_accuracy: 0.3966
# Epoch 91/200
# 391/391 - 27s - loss: 1.9848 - accuracy: 0.4610 - val_loss: 2.3765 - val_accuracy: 0.3962
# Epoch 92/200
# 391/391 - 27s - loss: 1.9851 - accuracy: 0.4593 - val_loss: 2.3799 - val_accuracy: 0.4002
# Epoch 93/200
# 391/391 - 28s - loss: 1.9753 - accuracy: 0.4629 - val_loss: 2.3969 - val_accuracy: 0.3938
# Epoch 94/200
# 391/391 - 28s - loss: 1.9710 - accuracy: 0.4617 - val_loss: 2.3696 - val_accuracy: 0.3956
# Epoch 95/200
# 391/391 - 28s - loss: 1.9754 - accuracy: 0.4602 - val_loss: 2.3874 - val_accuracy: 0.3964
# Epoch 96/200
# 391/391 - 27s - loss: 1.9685 - accuracy: 0.4629 - val_loss: 2.3636 - val_accuracy: 0.4006
# Epoch 97/200
# 391/391 - 27s - loss: 1.9680 - accuracy: 0.4634 - val_loss: 2.3596 - val_accuracy: 0.4038
# Epoch 98/200
# 391/391 - 27s - loss: 1.9614 - accuracy: 0.4637 - val_loss: 2.3607 - val_accuracy: 0.4021
# Epoch 99/200
# 391/391 - 27s - loss: 1.9646 - accuracy: 0.4620 - val_loss: 2.3565 - val_accuracy: 0.4008
# Epoch 100/200
# 391/391 - 27s - loss: 1.9555 - accuracy: 0.4656 - val_loss: 2.3724 - val_accuracy: 0.3983
# Epoch 101/200
# 391/391 - 27s - loss: 1.9340 - accuracy: 0.4700 - val_loss: 2.3770 - val_accuracy: 0.4061
# Epoch 102/200
# 391/391 - 27s - loss: 1.9237 - accuracy: 0.4744 - val_loss: 2.3529 - val_accuracy: 0.4053
# Epoch 103/200
# 391/391 - 28s - loss: 1.9170 - accuracy: 0.4763 - val_loss: 2.3659 - val_accuracy: 0.4008
# Epoch 104/200
# 391/391 - 28s - loss: 1.9207 - accuracy: 0.4746 - val_loss: 2.3498 - val_accuracy: 0.4083
# Epoch 105/200
# 391/391 - 27s - loss: 1.9260 - accuracy: 0.4760 - val_loss: 2.3635 - val_accuracy: 0.4073
# Epoch 106/200
# 391/391 - 27s - loss: 1.9152 - accuracy: 0.4776 - val_loss: 2.3509 - val_accuracy: 0.4037
# Epoch 107/200
# 391/391 - 27s - loss: 1.9037 - accuracy: 0.4776 - val_loss: 2.3639 - val_accuracy: 0.4035
# Epoch 108/200
# 391/391 - 28s - loss: 1.9084 - accuracy: 0.4760 - val_loss: 2.3639 - val_accuracy: 0.4027
# Epoch 109/200
# 391/391 - 27s - loss: 1.9050 - accuracy: 0.4791 - val_loss: 2.3653 - val_accuracy: 0.4017
# Epoch 110/200
# 391/391 - 27s - loss: 1.9051 - accuracy: 0.4765 - val_loss: 2.3546 - val_accuracy: 0.4087
# Epoch 111/200
# 391/391 - 27s - loss: 1.9039 - accuracy: 0.4786 - val_loss: 2.3569 - val_accuracy: 0.4052
# Epoch 112/200
# 391/391 - 27s - loss: 1.8971 - accuracy: 0.4805 - val_loss: 2.3791 - val_accuracy: 0.4028
# Epoch 113/200
# 391/391 - 27s - loss: 1.8963 - accuracy: 0.4805 - val_loss: 2.3619 - val_accuracy: 0.4049
# Epoch 114/200
# 391/391 - 27s - loss: 1.9004 - accuracy: 0.4771 - val_loss: 2.3656 - val_accuracy: 0.4025
# Epoch 115/200
# 391/391 - 27s - loss: 1.8896 - accuracy: 0.4804 - val_loss: 2.3752 - val_accuracy: 0.4038
# Epoch 116/200
# 391/391 - 27s - loss: 1.8971 - accuracy: 0.4795 - val_loss: 2.3842 - val_accuracy: 0.4023
# Epoch 117/200
# 391/391 - 27s - loss: 1.8874 - accuracy: 0.4809 - val_loss: 2.3620 - val_accuracy: 0.4061
# Epoch 118/200
# 391/391 - 27s - loss: 1.8920 - accuracy: 0.4825 - val_loss: 2.3908 - val_accuracy: 0.4037
# Epoch 119/200
# 391/391 - 27s - loss: 1.8851 - accuracy: 0.4815 - val_loss: 2.3806 - val_accuracy: 0.4046
# Epoch 120/200
# 391/391 - 27s - loss: 1.8822 - accuracy: 0.4810 - val_loss: 2.3647 - val_accuracy: 0.4047
# Epoch 121/200
# 391/391 - 27s - loss: 1.8662 - accuracy: 0.4865 - val_loss: 2.3776 - val_accuracy: 0.4029
# Epoch 122/200
# 391/391 - 27s - loss: 1.8670 - accuracy: 0.4862 - val_loss: 2.3653 - val_accuracy: 0.4051
# Epoch 123/200
# 391/391 - 27s - loss: 1.8631 - accuracy: 0.4878 - val_loss: 2.3676 - val_accuracy: 0.4028
# Epoch 124/200
# 391/391 - 27s - loss: 1.8614 - accuracy: 0.4874 - val_loss: 2.3673 - val_accuracy: 0.4059
# Epoch 125/200
# 391/391 - 27s - loss: 1.8592 - accuracy: 0.4893 - val_loss: 2.3660 - val_accuracy: 0.4075
# Epoch 126/200
# 391/391 - 27s - loss: 1.8597 - accuracy: 0.4873 - val_loss: 2.3672 - val_accuracy: 0.4071
# Epoch 127/200
# 391/391 - 27s - loss: 1.8579 - accuracy: 0.4872 - val_loss: 2.3801 - val_accuracy: 0.4058
# Epoch 128/200
# 391/391 - 27s - loss: 1.8557 - accuracy: 0.4890 - val_loss: 2.3717 - val_accuracy: 0.4062
# Epoch 129/200
# 391/391 - 27s - loss: 1.8587 - accuracy: 0.4865 - val_loss: 2.3807 - val_accuracy: 0.4064
# Epoch 130/200
# 391/391 - 27s - loss: 1.8528 - accuracy: 0.4904 - val_loss: 2.3712 - val_accuracy: 0.4067
# Epoch 131/200
# 391/391 - 27s - loss: 1.8566 - accuracy: 0.4874 - val_loss: 2.3644 - val_accuracy: 0.4058
# Epoch 132/200
# 391/391 - 26s - loss: 1.8543 - accuracy: 0.4890 - val_loss: 2.3801 - val_accuracy: 0.4039
# Epoch 133/200
# 391/391 - 26s - loss: 1.8431 - accuracy: 0.4918 - val_loss: 2.3762 - val_accuracy: 0.4053
# Epoch 134/200
# 391/391 - 27s - loss: 1.8449 - accuracy: 0.4909 - val_loss: 2.3654 - val_accuracy: 0.4069
# Epoch 135/200
# 391/391 - 26s - loss: 1.8402 - accuracy: 0.4915 - val_loss: 2.3790 - val_accuracy: 0.4053
# Epoch 136/200
# 391/391 - 26s - loss: 1.8404 - accuracy: 0.4922 - val_loss: 2.3782 - val_accuracy: 0.4044
# Epoch 137/200
# 391/391 - 27s - loss: 1.8453 - accuracy: 0.4922 - val_loss: 2.3801 - val_accuracy: 0.4048
# Epoch 138/200
# 391/391 - 26s - loss: 1.8468 - accuracy: 0.4899 - val_loss: 2.3668 - val_accuracy: 0.4084
# Epoch 139/200
# 391/391 - 27s - loss: 1.8445 - accuracy: 0.4908 - val_loss: 2.3870 - val_accuracy: 0.4053
# Epoch 140/200
# 391/391 - 27s - loss: 1.8459 - accuracy: 0.4896 - val_loss: 2.3781 - val_accuracy: 0.4061

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import pandas as pd
from keras.datasets import cifar100
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_test = x_test.astype('float32')
x_test = x_test / 255.0
y_pred = model.predict(x_test)
y_pred=np.argmax(y_pred,axis=1)
y_pred=pd.DataFrame(y_pred)
y_test=pd.DataFrame(y_test)

p=precision_score(y_test, y_pred,average='weighted',labels=np.unique(y_pred))
r=recall_score(y_test,y_pred,average='micro',labels=np.unique(y_pred))
print('Precision Is:',p)
print('Recall Is:',r)
# Out:
# Precision Is: 0.4080166821587506
# Recall Is: 0.4061
